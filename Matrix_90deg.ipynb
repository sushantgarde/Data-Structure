# %%
import numpy as np

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
rotated = list(zip(*matrix[::-1]))

# %%
for i in range(len(matrix)):
    matrix[i] = list(rotated[i])

# %%
matrix
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]
